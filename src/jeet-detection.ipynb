# %%
import librosa
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json
import os

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report,accuracy_score,precision_score,recall_score

# %%
DATA_ROOT = '../data/openmic-2018'

if not os.path.exists(DATA_ROOT):
    raise ValueError('Did you forget to set `DATA_ROOT`?')

# %%
OPENMIC = np.load(os.path.join(DATA_ROOT, 'openmic-2018.npz'), allow_pickle=True)

# %%
#we will overwrite 'X' later
X, Y_true, Y_mask, sample_key = OPENMIC['X'], OPENMIC['Y_true'], OPENMIC['Y_mask'], OPENMIC['sample_key']

# %%
features=pd.read_csv('features.csv')
features
# Out:
#           sample_key  zcr_mean   zcr_std     sc_mean      sc_std     sb_mean  \
# 0        000046_3840  0.036367  0.021923  296.517136  133.109808  288.159666
# 1      000135_483840  0.052411  0.013491  478.192757  141.199973  409.844515
# 2      000139_119040  0.081234  0.014925  604.505859  189.731508  719.222449
# 3      000141_153600  0.053718  0.013248  462.825122  153.244140  391.783679
# 4       000144_30720  0.082449  0.034076  601.706717  329.074617  766.763811
# ...              ...       ...       ...         ...         ...         ...
# 19995  155294_184320  0.050435  0.009352  508.286842   94.249039  266.331118
# 19996   155295_76800  0.009752  0.004809   61.216410   42.815086  101.288169
# 19997  155307_211200  0.065545  0.022368  450.432458  192.751011  665.939788
# 19998  155310_372480  0.042145  0.015084  332.139261  146.760990  409.563611
# 19999  155311_453120  0.039820  0.016151  300.841059  117.395470  388.035180
#
#            sb_std     sr_mean      sr_std   mfcc1_mean  ...  mfcc9_mean  \
# 0      267.139540  288.159666  267.139540   147.188060  ...   166.07562
# 1      135.532246  409.844515  135.532246  1282.769400  ...   765.03280
# 2      139.070343  719.222449  139.070343   292.690280  ...   214.49968
# 3       84.894649  391.783679   84.894649   188.996630  ...   146.75562
# 4      375.408621  766.763811  375.408621   196.932450  ...   172.74915
# ...           ...         ...         ...          ...  ...         ...
# 19995   63.090107  266.331118   63.090107   147.754410  ...    75.58570
# 19996   53.390921  101.288169   53.390921   631.029240  ...   866.60800
# 19997  285.751704  665.939788  285.751704   100.515335  ...    87.85434
# 19998  169.775745  409.563611  169.775745   144.219150  ...   139.86327
# 19999  205.422401  388.035180  205.422401   254.896030  ...   273.97130
#
#         mfcc9std  mfcc10_mean   mfcc10std  mfcc11_mean  mfcc11std  \
# 0      216.15845   158.768600  209.785170   151.586730  203.43971
# 1      495.68510   590.328800  558.758240   425.313660  616.81950
# 2      316.38672   198.657150  314.673430   186.793670  313.87470
# 3      140.59268   130.843980  137.768260   116.143745  135.27222
# 4      268.45245   166.110350  266.885220   159.133510  265.19022
# ...          ...          ...         ...          ...        ...
# 19995   66.08795    52.333115   52.021423    29.923525   44.92963
# 19996  485.64580   861.181340  485.591300   855.655100  485.54526
# 19997  141.25677    81.044754  138.202670    74.912180  134.90385
# 19998  216.60248   130.948000  216.237840   122.950190  216.05978
# 19999  215.41476   259.883360  210.476330   245.089900  205.54100
#
#        mfcc12_mean  mfcc12std  mfcc13_mean  mfcc13std
# 0       144.200240  197.13676   136.577680  190.80775
# 1       274.802150  663.55350   142.181600  694.35410
# 2       177.732700  313.87650   170.007640  313.99084
# 3       102.521700  133.01720    89.947320  130.88220
# 4       151.693700  263.76523   143.998100  262.70773
# ...            ...        ...          ...        ...
# 19995     8.635664   46.96052   -11.322803   55.88632
# 19996   850.119600  485.50488   844.646670  485.46692
# 19997    69.371315  131.49872    64.451385  128.12172
# 19998   116.407776  216.06279   111.108376  216.22318
# 19999   230.410980  201.05861   216.157270  197.14174
#
# [20000 rows x 35 columns]

# %%
features.columns
# Out:
# Index(['sample_key', 'zcr_mean', 'zcr_std', 'sc_mean', 'sc_std', 'sb_mean',
#        'sb_std', 'sr_mean', 'sr_std', 'mfcc1_mean', 'mfcc1std', 'mfcc2_mean',
#        'mfcc2std', 'mfcc3_mean', 'mfcc3std', 'mfcc4_mean', 'mfcc4std',
#        'mfcc5_mean', 'mfcc5std', 'mfcc6_mean', 'mfcc6std', 'mfcc7_mean',
#        'mfcc7std', 'mfcc8_mean', 'mfcc8std', 'mfcc9_mean', 'mfcc9std',
#        'mfcc10_mean', 'mfcc10std', 'mfcc11_mean', 'mfcc11std', 'mfcc12_mean',
#        'mfcc12std', 'mfcc13_mean', 'mfcc13std'],
#       dtype='object')

# %%
#The data
# TODO what is "the data"??????????????????????????????????????????????????????????
X=np.array(features.iloc[:,2:]) # <---- magic number!!!!!

# %%
split_train = pd.read_csv(
    os.path.join(DATA_ROOT, "partitions/split01_train.csv"), header=None,
).squeeze("columns")
split_test = pd.read_csv(
    os.path.join(DATA_ROOT, "partitions/split01_test.csv"), header=None,
).squeeze("columns")

split_test.head()
# Out:
# 0      000178_3840
# 1     000308_61440
# 2    000312_184320
# 3    000319_145920
# 4    000321_218880
# Name: 0, dtype: object

# %%
print('# Train: {},  # Test: {}'.format(len(split_train), len(split_test)))
# Out:
# # Train: 14915,  # Test: 5085

# %%
train_set = set(split_train)
test_set = set(split_test)

# %%
# These loops go through all sample keys, and save their row numbers
# to either idx_train or idx_test
#
# This will be useful in the next step for slicing the array data
idx_train, idx_test = [], []

for idx, n in enumerate(sample_key):
    if n in train_set:
        idx_train.append(idx)
    elif n in test_set:
        idx_test.append(idx)
    else:
        # This should never happen, but better safe than sorry.
        raise RuntimeError('Unknown sample key={}! Abort!'.format(sample_key[n]))
        
# Finally, cast the idx_* arrays to numpy structures
idx_train = np.asarray(idx_train)
idx_test = np.asarray(idx_test)

# %%
# Finally, we use the split indices to partition the features, labels, and masks
X_train = X[idx_train]
X_test = X[idx_test]

Y_true_train = Y_true[idx_train]
Y_true_test = Y_true[idx_test]

Y_mask_train = Y_mask[idx_train]
Y_mask_test = Y_mask[idx_test]

# %%
# Print out the sliced shapes as a sanity check
print(X_train.shape)
print(X_test.shape)
# Out:
# (14915, 33)
# (5085, 33)

# %%
with open(os.path.join(DATA_ROOT, 'class-map.json'), 'r') as f:
    class_map = json.load(f)
class_map
# Out:
# {'accordion': 0,
#  'banjo': 1,
#  'bass': 2,
#  'cello': 3,
#  'clarinet': 4,
#  'cymbals': 5,
#  'drums': 6,
#  'flute': 7,
#  'guitar': 8,
#  'mallet_percussion': 9,
#  'mandolin': 10,
#  'organ': 11,
#  'piano': 12,
#  'saxophone': 13,
#  'synthesizer': 14,
#  'trombone': 15,
#  'trumpet': 16,
#  'ukulele': 17,
#  'violin': 18,
#  'voice': 19}

# %% [markdown]
# # Model training
#
# Since the OPENMIC dataset is an ongoing project, and still acquiring annotations, we found it a bit hard to mold the data. Out of convienence, we are using the approach in [modelling baseline](https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb), as suggested by the authors of the dataset.

# %% [markdown]
# First, we are replicating the method of [PMICSF](https://arxiv.org/abs/1912.02606), and so, only looking at six instrument:
#
# ```python
#     ['flute', 'guitar', 'organ', 'piano', 'trumpet', 'voice']
# ```

# %%
import numpy as np

instruments = ['accordion', 'banjo', 'bass', 'cello', 'clarinet',
       'cymbals', 'drums', 'flute', 'guitar', 'mallet_percussion', 'mandolin',
       'organ', 'piano', 'saxophone', 'synthesizer', 'trombone', 'trumpet',
       'ukulele', 'violin', 'voice']

article_instruments = ['flute', 'guitar', 'organ', 'piano', 'trumpet', 'voice']

features = ['zcr_mean', 'zcr_std', 'sc_mean',
       'sc_std', 'sb_mean', 'sb_std', 'sr_mean', 'sr_std', 'mfcc1_mean',
       'mfcc1std', 'mfcc2_mean', 'mfcc2std', 'mfcc3_mean', 'mfcc3std',
       'mfcc4_mean', 'mfcc4std', 'mfcc5_mean', 'mfcc5std', 'mfcc6_mean',
       'mfcc6std', 'mfcc7_mean', 'mfcc7std', 'mfcc8_mean', 'mfcc8std',
       'mfcc9_mean', 'mfcc9std', 'mfcc10_mean', 'mfcc10std', 'mfcc11_mean',
       'mfcc11std', 'mfcc12_mean', 'mfcc12std', 'mfcc13_mean', 'mfcc13std']

article_features = ['zcr_mean', 'sc_mean', 'sb_mean', 'sr_mean', 'mfcc1_mean',
       'mfcc2_mean', 'mfcc3_mean', 'mfcc4_mean', 'mfcc5_mean', 'mfcc6_mean',
       'mfcc7_mean', 'mfcc8_mean', 'mfcc9_mean', 'mfcc10_mean', 'mfcc11_mean',
       'mfcc12_mean', 'mfcc13_mean']

# %% [markdown]
# We have the choice to replicate the article features and instruments, or picking some additional features we used.
# Our baseline is the article features:

# %%
FEATURES = article_features
INSTRUMENTS = article_instruments

# %% [markdown]
# ## Modeling baseline
#
# We took the approach of previously mentioned [modelling baseline](https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb) and turned it into a method:

# %%
def modelling_baseline(X_train, X_test, Y_true_train, Y_true_test, Y_mask_train, Y_mask_test, class_map, clf, instruments, output_dict=True):
    """
    Use the modeling baseline to train a classifier for each instrument
    Returns randomforrest_models - classifiers for trained model
            reports - classification reports for each instrument
            accuracies - accuracies for each instrument
    """
    # This dictionary will include the classifiers for each model
    models = dict()
    reports = dict()
    accuracies = dict()


    # We'll iterate over all istrument classes, and fit a model for each one
    # After training, we'll print a classification report for each instrument
    for instrument in instruments:

        # Map the instrument name to its column number
        inst_num = class_map[instrument]

        # Step 1: sub-sample the data

        # First, we need to select down to the data for which we have annotations
        # This is what the mask arrays are for
        train_inst = Y_mask_train[:, inst_num]
        test_inst = Y_mask_test[:, inst_num]

        # Here, we're using the Y_mask_train array to slice out only the training examples
        # for which we have annotations for the given class
        X_train_inst = X_train[train_inst]

        # Again, we slice the labels to the annotated examples
        # We thresold the label likelihoods at 0.5 to get binary labels
        Y_true_train_inst = Y_true_train[train_inst, inst_num] >= 0.5

        # Repeat the above slicing and dicing but for the test set
        X_test_inst = X_test[test_inst]
        Y_true_test_inst = Y_true_test[test_inst, inst_num] >= 0.5

        # Step 3.
        # Initialize a new classifier
        # No

        # Step 4.
        clf.fit(X_train_inst, Y_true_train_inst)

        # Step 5.
        # Finally, evaluate the model on both test data
        Y_pred_test = clf.predict(X_test_inst)
        
        # Store the classifier in our dictionary
        models[instrument] = clf
        reports[instrument] = classification_report(Y_true_test_inst, Y_pred_test, output_dict=output_dict)
        accuracies[instrument] = accuracy_score(Y_true_test_inst, Y_pred_test)

    return models, reports, accuracies

# %% [markdown]
# Let's store all results in a dictionary. If you want to find the result of a specific model, you can use the following baseline.
#
# ```python
#     >>> results['RandomForest']['Accuracy']['flute']
#     0.5925925925925926
# ```

# %%
keys = {"model": None, "report": None, "accuracy": None}

models = ['RandomForest', 'SVM', 'LogisticRegression', 'GradientBoost', 'DecisionTree', 'LGBM']

results = dict()

for model in models:
    results[model] = dict(keys)

"""results = {
    'RandomForest': dict(keys),
    'SVM': dict(keys),
    'LogisticRegression': dict(keys),
    'GradientBoost': dict(keys),
    'DecisionTree': dict(keys),
    'LGBM': dict(keys),
}"""

results
# Out:
# {'RandomForest': {'model': None, 'report': None, 'accuracy': None},
#  'SVM': {'model': None, 'report': None, 'accuracy': None},
#  'LogisticRegression': {'model': None, 'report': None, 'accuracy': None},
#  'GradientBoost': {'model': None, 'report': None, 'accuracy': None},
#  'DecisionTree': {'model': None, 'report': None, 'accuracy': None},
#  'LGBM': {'model': None, 'report': None, 'accuracy': None}}

# %% [markdown]
# #  Random Forest Classifier

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)

model, reports, accuracies = modelling_baseline(X_train, 
                                                X_test, 
                                                Y_true_train, 
                                                Y_true_test, 
                                                Y_mask_train, 
                                                Y_mask_test, 
                                                class_map, 
                                                clf, 
                                                INSTRUMENTS)

results['RandomForest']['model'] = model
results['RandomForest']['report'] = reports
results['RandomForest']['accuracy'] = accuracies

# %% [markdown]
# # SVM

# %%
# UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior.
clf = SVC()

model, reports, accuracies = modelling_baseline(X_train, 
                                                X_test, 
                                                Y_true_train, 
                                                Y_true_test, 
                                                Y_mask_train, 
                                                Y_mask_test, 
                                                class_map, 
                                                clf, 
                                                INSTRUMENTS)

results['SVM']['model'] = model
results['SVM']['report'] = reports
results['SVM']['accuracy'] = accuracies
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Decision Trees

# %%
clf = DecisionTreeClassifier()

model, reports, accuracies = modelling_baseline(X_train, 
                                                X_test, 
                                                Y_true_train, 
                                                Y_true_test, 
                                                Y_mask_train, 
                                                Y_mask_test, 
                                                class_map, 
                                                clf, 
                                                INSTRUMENTS)

results['DecisionTree']['model'] = model
results['DecisionTree']['report'] = reports
results['DecisionTree']['accuracy'] = accuracies

# %% [markdown]
# # Gradient Boosting

# %%
clf = GradientBoostingClassifier(learning_rate=0.3)

model, reports, accuracies = modelling_baseline(X_train, 
                                                X_test, 
                                                Y_true_train, 
                                                Y_true_test, 
                                                Y_mask_train, 
                                                Y_mask_test, 
                                                class_map, 
                                                clf, 
                                                INSTRUMENTS)

results['GradientBoost']['model'] = model
results['GradientBoost']['report'] = reports
results['GradientBoost']['accuracy'] = accuracies

# %% [markdown]
# # Logistic Regression

# %%
clf = LogisticRegression(max_iter=50)

model, reports, accuracies = modelling_baseline(X_train, 
                                                X_test, 
                                                Y_true_train, 
                                                Y_true_test, 
                                                Y_mask_train, 
                                                Y_mask_test, 
                                                class_map, 
                                                clf, 
                                                INSTRUMENTS)

results['LogisticRegression']['model'] = model
results['LogisticRegression']['report'] = reports
results['LogisticRegression']['accuracy'] = accuracies
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # LGBM

# %%
clf = LGBMClassifier()

model, reports, accuracies = modelling_baseline(X_train, 
                                                X_test, 
                                                Y_true_train, 
                                                Y_true_test, 
                                                Y_mask_train, 
                                                Y_mask_test, 
                                                class_map, 
                                                clf, 
                                                INSTRUMENTS)

results['LGBM']['model'] = model
results['LGBM']['report'] = reports
results['LGBM']['accuracy'] = accuracies

# %% [markdown]
# # Results

# %%
m = np.mean(list(results['SVM']['accuracy'].values()))
std = np.std(list(results['SVM']['accuracy'].values()))
print(m, std)
# Out:
# 0.727461493998946 0.06975715340387725

# %%
# den här outputten kan man använda för att skapa ett table med copilot
#instrument = 'flute'
#model = 'DecisionTree'
article_columns = ['P', 'R', 'F1', 'support']

columns = ["precision",	"recall", "f1-score", "support", "model", "instrument"]
df = pd.DataFrame(columns=columns)
df = df.rename(columns={ "precision": "P", 
                    "recall": "R", 
                    "f1-score": "F1"
                    }, inplace=True)

for instrument in INSTRUMENTS:
    for model in models:
        di = results[model]["report"][instrument]['True']
        di['model'] = model
        di['instrument'] = instrument
        df = pd.concat([df, pd.DataFrame(di, index=[0]).rename(columns={ "precision": "P", 
                    "recall": "R", 
                    "f1-score": "F1",
                    }).drop(columns=['support'])], ignore_index=True)
        #df.to_latex(buf="../tables/" + model + ".tex", index=False)

n_rows, n_cols = df.shape
df_melted = df.melt(id_vars=["model", "instrument"], var_name="metric", value_name="value")

df_pivot = df_melted.pivot_table(columns=['model', "metric"], 
                        index=['instrument'], 
                        values=['value'], 
                        aggfunc='mean'
                        )
#df_tex = df_pivot.style.to_latex(float_format="%.2f", 
#                            multicolumn=True, 
#                            multirow=True)
#df_tex = df_tex.replace("multirow{6}{*}{", "multirow{6}{*}{\\rotatebox[origin=c]{90}{")

df_pivot
# Out:
#                   value                                                        \
# model      DecisionTree                     GradientBoost
# metric               F1         P         R            F1         P         R
# instrument
# flute          0.425197  0.393204  0.462857      0.342657  0.441441  0.280000
# guitar         0.770035  0.767361  0.772727      0.818923  0.767584  0.877622
# organ          0.381743  0.383333  0.380165      0.364486  0.419355  0.322314
# piano          0.857658  0.881481  0.835088      0.902439  0.896194  0.908772
# trumpet        0.492308  0.481928  0.503145      0.499145  0.546816  0.459119
# voice          0.706131  0.670683  0.745536      0.810484  0.738971  0.897321
#
#                                                                        \
# model           LGBM                     LogisticRegression
# metric            F1         P         R                 F1         P
# instrument
# flute       0.377224  0.500000  0.302857           0.081218  0.363636
# guitar      0.819835  0.777429  0.867133           0.812983  0.728532
# organ       0.339623  0.395604  0.297521           0.233129  0.452381
# piano       0.901893  0.885135  0.919298           0.900169  0.869281
# trumpet     0.519737  0.544828  0.496855           0.369295  0.542683
# voice       0.808765  0.730216  0.906250           0.797665  0.706897
#
#                                                                            \
# model                RandomForest                           SVM
# metric             R           F1         P         R        F1         P
# instrument
# flute       0.045714     0.328000  0.546667  0.234286  0.000000  0.000000
# guitar      0.919580     0.831424  0.781538  0.888112  0.820059  0.709184
# organ       0.157025     0.366492  0.500000  0.289256  0.211921  0.533333
# piano       0.933333     0.902998  0.907801  0.898246  0.905405  0.872964
# trumpet     0.279874     0.474048  0.526923  0.430818  0.473394  0.568282
# voice       0.915179     0.792829  0.715827  0.888393  0.803150  0.718310
#
#
# model
# metric             R
# instrument
# flute       0.000000
# guitar      0.972028
# organ       0.132231
# piano       0.940351
# trumpet     0.405660
# voice       0.910714

# %%
df_pivot[df_pivot.columns[0:9]].style.format("{:.2f}").background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_bd3a6_row0_col0 {
#   background-color: #feecd2;
#   color: #000000;
# }
# #T_bd3a6_row0_col1 {
#   background-color: #fff5e6;
#   color: #000000;
# }
# #T_bd3a6_row0_col2 {
#   background-color: #fedfb5;
#   color: #000000;
# }
# #T_bd3a6_row0_col3, #T_bd3a6_row0_col5, #T_bd3a6_row2_col0, #T_bd3a6_row2_col1, #T_bd3a6_row2_col2, #T_bd3a6_row2_col4, #T_bd3a6_row2_col6, #T_bd3a6_row2_col7, #T_bd3a6_row2_col8 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_bd3a6_row0_col4 {
#   background-color: #fff2e0;
#   color: #000000;
# }
# #T_bd3a6_row0_col6, #T_bd3a6_row2_col5 {
#   background-color: #feefd9;
#   color: #000000;
# }
# #T_bd3a6_row0_col7 {
#   background-color: #fddaab;
#   color: #000000;
# }
# #T_bd3a6_row0_col8 {
#   background-color: #fff6ea;
#   color: #000000;
# }
# #T_bd3a6_row1_col0 {
#   background-color: #c4170f;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col1 {
#   background-color: #d12719;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col2 {
#   background-color: #b70503;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col3 {
#   background-color: #ba0906;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col4 {
#   background-color: #db3926;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col5 {
#   background-color: #930000;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col6 {
#   background-color: #b90805;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col7 {
#   background-color: #ce2417;
#   color: #f1f1f1;
# }
# #T_bd3a6_row1_col8 {
#   background-color: #a10000;
#   color: #f1f1f1;
# }
# #T_bd3a6_row2_col3 {
#   background-color: #fff3e2;
#   color: #000000;
# }
# #T_bd3a6_row3_col0, #T_bd3a6_row3_col1, #T_bd3a6_row3_col2, #T_bd3a6_row3_col3, #T_bd3a6_row3_col4, #T_bd3a6_row3_col5, #T_bd3a6_row3_col6, #T_bd3a6_row3_col7, #T_bd3a6_row3_col8 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_bd3a6_row4_col0 {
#   background-color: #fdd7a4;
#   color: #000000;
# }
# #T_bd3a6_row4_col1 {
#   background-color: #fdddb0;
#   color: #000000;
# }
# #T_bd3a6_row4_col2 {
#   background-color: #fdd09a;
#   color: #000000;
# }
# #T_bd3a6_row4_col3 {
#   background-color: #fdce98;
#   color: #000000;
# }
# #T_bd3a6_row4_col4 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_bd3a6_row4_col5 {
#   background-color: #fdce97;
#   color: #000000;
# }
# #T_bd3a6_row4_col6, #T_bd3a6_row4_col8 {
#   background-color: #fdc68f;
#   color: #000000;
# }
# #T_bd3a6_row4_col7 {
#   background-color: #fdc992;
#   color: #000000;
# }
# #T_bd3a6_row5_col0, #T_bd3a6_row5_col7 {
#   background-color: #e44d35;
#   color: #f1f1f1;
# }
# #T_bd3a6_row5_col1 {
#   background-color: #f4754f;
#   color: #f1f1f1;
# }
# #T_bd3a6_row5_col2 {
#   background-color: #c71b12;
#   color: #f1f1f1;
# }
# #T_bd3a6_row5_col3, #T_bd3a6_row5_col6 {
#   background-color: #be0f0a;
#   color: #f1f1f1;
# }
# #T_bd3a6_row5_col4 {
#   background-color: #e65239;
#   color: #f1f1f1;
# }
# #T_bd3a6_row5_col5 {
#   background-color: #860000;
#   color: #f1f1f1;
# }
# #T_bd3a6_row5_col8 {
#   background-color: #870000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bd3a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd3a6_level0_col0" class="col_heading level0 col0" colspan="9">value</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >model</th>
#       <th id="T_bd3a6_level1_col0" class="col_heading level1 col0" colspan="3">DecisionTree</th>
#       <th id="T_bd3a6_level1_col3" class="col_heading level1 col3" colspan="3">GradientBoost</th>
#       <th id="T_bd3a6_level1_col6" class="col_heading level1 col6" colspan="3">LGBM</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >metric</th>
#       <th id="T_bd3a6_level2_col0" class="col_heading level2 col0" >F1</th>
#       <th id="T_bd3a6_level2_col1" class="col_heading level2 col1" >P</th>
#       <th id="T_bd3a6_level2_col2" class="col_heading level2 col2" >R</th>
#       <th id="T_bd3a6_level2_col3" class="col_heading level2 col3" >F1</th>
#       <th id="T_bd3a6_level2_col4" class="col_heading level2 col4" >P</th>
#       <th id="T_bd3a6_level2_col5" class="col_heading level2 col5" >R</th>
#       <th id="T_bd3a6_level2_col6" class="col_heading level2 col6" >F1</th>
#       <th id="T_bd3a6_level2_col7" class="col_heading level2 col7" >P</th>
#       <th id="T_bd3a6_level2_col8" class="col_heading level2 col8" >R</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >instrument</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd3a6_level0_row0" class="row_heading level0 row0" >flute</th>
#       <td id="T_bd3a6_row0_col0" class="data row0 col0" >0.43</td>
#       <td id="T_bd3a6_row0_col1" class="data row0 col1" >0.39</td>
#       <td id="T_bd3a6_row0_col2" class="data row0 col2" >0.46</td>
#       <td id="T_bd3a6_row0_col3" class="data row0 col3" >0.34</td>
#       <td id="T_bd3a6_row0_col4" class="data row0 col4" >0.44</td>
#       <td id="T_bd3a6_row0_col5" class="data row0 col5" >0.28</td>
#       <td id="T_bd3a6_row0_col6" class="data row0 col6" >0.38</td>
#       <td id="T_bd3a6_row0_col7" class="data row0 col7" >0.50</td>
#       <td id="T_bd3a6_row0_col8" class="data row0 col8" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_bd3a6_level0_row1" class="row_heading level0 row1" >guitar</th>
#       <td id="T_bd3a6_row1_col0" class="data row1 col0" >0.77</td>
#       <td id="T_bd3a6_row1_col1" class="data row1 col1" >0.77</td>
#       <td id="T_bd3a6_row1_col2" class="data row1 col2" >0.77</td>
#       <td id="T_bd3a6_row1_col3" class="data row1 col3" >0.82</td>
#       <td id="T_bd3a6_row1_col4" class="data row1 col4" >0.77</td>
#       <td id="T_bd3a6_row1_col5" class="data row1 col5" >0.88</td>
#       <td id="T_bd3a6_row1_col6" class="data row1 col6" >0.82</td>
#       <td id="T_bd3a6_row1_col7" class="data row1 col7" >0.78</td>
#       <td id="T_bd3a6_row1_col8" class="data row1 col8" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_bd3a6_level0_row2" class="row_heading level0 row2" >organ</th>
#       <td id="T_bd3a6_row2_col0" class="data row2 col0" >0.38</td>
#       <td id="T_bd3a6_row2_col1" class="data row2 col1" >0.38</td>
#       <td id="T_bd3a6_row2_col2" class="data row2 col2" >0.38</td>
#       <td id="T_bd3a6_row2_col3" class="data row2 col3" >0.36</td>
#       <td id="T_bd3a6_row2_col4" class="data row2 col4" >0.42</td>
#       <td id="T_bd3a6_row2_col5" class="data row2 col5" >0.32</td>
#       <td id="T_bd3a6_row2_col6" class="data row2 col6" >0.34</td>
#       <td id="T_bd3a6_row2_col7" class="data row2 col7" >0.40</td>
#       <td id="T_bd3a6_row2_col8" class="data row2 col8" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_bd3a6_level0_row3" class="row_heading level0 row3" >piano</th>
#       <td id="T_bd3a6_row3_col0" class="data row3 col0" >0.86</td>
#       <td id="T_bd3a6_row3_col1" class="data row3 col1" >0.88</td>
#       <td id="T_bd3a6_row3_col2" class="data row3 col2" >0.84</td>
#       <td id="T_bd3a6_row3_col3" class="data row3 col3" >0.90</td>
#       <td id="T_bd3a6_row3_col4" class="data row3 col4" >0.90</td>
#       <td id="T_bd3a6_row3_col5" class="data row3 col5" >0.91</td>
#       <td id="T_bd3a6_row3_col6" class="data row3 col6" >0.90</td>
#       <td id="T_bd3a6_row3_col7" class="data row3 col7" >0.89</td>
#       <td id="T_bd3a6_row3_col8" class="data row3 col8" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_bd3a6_level0_row4" class="row_heading level0 row4" >trumpet</th>
#       <td id="T_bd3a6_row4_col0" class="data row4 col0" >0.49</td>
#       <td id="T_bd3a6_row4_col1" class="data row4 col1" >0.48</td>
#       <td id="T_bd3a6_row4_col2" class="data row4 col2" >0.50</td>
#       <td id="T_bd3a6_row4_col3" class="data row4 col3" >0.50</td>
#       <td id="T_bd3a6_row4_col4" class="data row4 col4" >0.55</td>
#       <td id="T_bd3a6_row4_col5" class="data row4 col5" >0.46</td>
#       <td id="T_bd3a6_row4_col6" class="data row4 col6" >0.52</td>
#       <td id="T_bd3a6_row4_col7" class="data row4 col7" >0.54</td>

# %%
df_pivot[df_pivot.columns[9:18]].style.format("{:.2f}").background_gradient(cmap='OrRd') #[['F1', 'P', 'R']]
# Out:
# <style type="text/css">
# #T_31584_row0_col0, #T_31584_row0_col1, #T_31584_row0_col2, #T_31584_row0_col3, #T_31584_row0_col5, #T_31584_row0_col6, #T_31584_row0_col7, #T_31584_row0_col8, #T_31584_row2_col4 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_31584_row0_col4 {
#   background-color: #fee9cb;
#   color: #000000;
# }
# #T_31584_row1_col0 {
#   background-color: #ab0000;
#   color: #f1f1f1;
# }
# #T_31584_row1_col1 {
#   background-color: #dc3c28;
#   color: #f1f1f1;
# }
# #T_31584_row1_col2, #T_31584_row1_col5, #T_31584_row5_col5 {
#   background-color: #840000;
#   color: #f1f1f1;
# }
# #T_31584_row1_col3 {
#   background-color: #b20000;
#   color: #f1f1f1;
# }
# #T_31584_row1_col4 {
#   background-color: #e24933;
#   color: #f1f1f1;
# }
# #T_31584_row1_col6 {
#   background-color: #a60000;
#   color: #f1f1f1;
# }
# #T_31584_row1_col7 {
#   background-color: #c51810;
#   color: #f1f1f1;
# }
# #T_31584_row1_col8, #T_31584_row3_col0, #T_31584_row3_col1, #T_31584_row3_col2, #T_31584_row3_col3, #T_31584_row3_col4, #T_31584_row3_col5, #T_31584_row3_col6, #T_31584_row3_col7 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_31584_row2_col0 {
#   background-color: #fedfb4;
#   color: #000000;
# }
# #T_31584_row2_col1 {
#   background-color: #fee0b8;
#   color: #000000;
# }
# #T_31584_row2_col2 {
#   background-color: #fee8c8;
#   color: #000000;
# }
# #T_31584_row2_col3 {
#   background-color: #feefd9;
#   color: #000000;
# }
# #T_31584_row2_col5 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_31584_row2_col6 {
#   background-color: #fdd7a4;
#   color: #000000;
# }
# #T_31584_row2_col7 {
#   background-color: #f0694a;
#   color: #f1f1f1;
# }
# #T_31584_row2_col8 {
#   background-color: #fee7c5;
#   color: #000000;
# }
# #T_31584_row3_col8 {
#   background-color: #8c0000;
#   color: #f1f1f1;
# }
# #T_31584_row4_col0, #T_31584_row4_col1 {
#   background-color: #fdbf89;
#   color: #000000;
# }
# #T_31584_row4_col2 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_31584_row4_col3 {
#   background-color: #fdd39d;
#   color: #000000;
# }
# #T_31584_row4_col4 {
#   background-color: #feefda;
#   color: #000000;
# }
# #T_31584_row4_col5 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_31584_row4_col6 {
#   background-color: #fa8656;
#   color: #f1f1f1;
# }
# #T_31584_row4_col7 {
#   background-color: #ea5a3f;
#   color: #f1f1f1;
# }
# #T_31584_row4_col8 {
#   background-color: #fdac76;
#   color: #000000;
# }
# #T_31584_row5_col0 {
#   background-color: #b30000;
#   color: #f1f1f1;
# }
# #T_31584_row5_col1 {
#   background-color: #e54e36;
#   color: #f1f1f1;
# }
# #T_31584_row5_col2 {
#   background-color: #870000;
#   color: #f1f1f1;
# }
# #T_31584_row5_col3 {
#   background-color: #c61a11;
#   color: #f1f1f1;
# }
# #T_31584_row5_col4 {
#   background-color: #f98455;
#   color: #f1f1f1;
# }
# #T_31584_row5_col6 {
#   background-color: #ad0000;
#   color: #f1f1f1;
# }
# #T_31584_row5_col7 {
#   background-color: #c2140d;
#   color: #f1f1f1;
# }
# #T_31584_row5_col8 {
#   background-color: #990000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31584">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31584_level0_col0" class="col_heading level0 col0" colspan="9">value</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >model</th>
#       <th id="T_31584_level1_col0" class="col_heading level1 col0" colspan="3">LogisticRegression</th>
#       <th id="T_31584_level1_col3" class="col_heading level1 col3" colspan="3">RandomForest</th>
#       <th id="T_31584_level1_col6" class="col_heading level1 col6" colspan="3">SVM</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >metric</th>
#       <th id="T_31584_level2_col0" class="col_heading level2 col0" >F1</th>
#       <th id="T_31584_level2_col1" class="col_heading level2 col1" >P</th>
#       <th id="T_31584_level2_col2" class="col_heading level2 col2" >R</th>
#       <th id="T_31584_level2_col3" class="col_heading level2 col3" >F1</th>
#       <th id="T_31584_level2_col4" class="col_heading level2 col4" >P</th>
#       <th id="T_31584_level2_col5" class="col_heading level2 col5" >R</th>
#       <th id="T_31584_level2_col6" class="col_heading level2 col6" >F1</th>
#       <th id="T_31584_level2_col7" class="col_heading level2 col7" >P</th>
#       <th id="T_31584_level2_col8" class="col_heading level2 col8" >R</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >instrument</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31584_level0_row0" class="row_heading level0 row0" >flute</th>
#       <td id="T_31584_row0_col0" class="data row0 col0" >0.08</td>
#       <td id="T_31584_row0_col1" class="data row0 col1" >0.36</td>
#       <td id="T_31584_row0_col2" class="data row0 col2" >0.05</td>
#       <td id="T_31584_row0_col3" class="data row0 col3" >0.33</td>
#       <td id="T_31584_row0_col4" class="data row0 col4" >0.55</td>
#       <td id="T_31584_row0_col5" class="data row0 col5" >0.23</td>
#       <td id="T_31584_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_31584_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_31584_row0_col8" class="data row0 col8" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_31584_level0_row1" class="row_heading level0 row1" >guitar</th>
#       <td id="T_31584_row1_col0" class="data row1 col0" >0.81</td>
#       <td id="T_31584_row1_col1" class="data row1 col1" >0.73</td>
#       <td id="T_31584_row1_col2" class="data row1 col2" >0.92</td>
#       <td id="T_31584_row1_col3" class="data row1 col3" >0.83</td>
#       <td id="T_31584_row1_col4" class="data row1 col4" >0.78</td>
#       <td id="T_31584_row1_col5" class="data row1 col5" >0.89</td>
#       <td id="T_31584_row1_col6" class="data row1 col6" >0.82</td>
#       <td id="T_31584_row1_col7" class="data row1 col7" >0.71</td>
#       <td id="T_31584_row1_col8" class="data row1 col8" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_31584_level0_row2" class="row_heading level0 row2" >organ</th>
#       <td id="T_31584_row2_col0" class="data row2 col0" >0.23</td>
#       <td id="T_31584_row2_col1" class="data row2 col1" >0.45</td>
#       <td id="T_31584_row2_col2" class="data row2 col2" >0.16</td>
#       <td id="T_31584_row2_col3" class="data row2 col3" >0.37</td>
#       <td id="T_31584_row2_col4" class="data row2 col4" >0.50</td>
#       <td id="T_31584_row2_col5" class="data row2 col5" >0.29</td>
#       <td id="T_31584_row2_col6" class="data row2 col6" >0.21</td>
#       <td id="T_31584_row2_col7" class="data row2 col7" >0.53</td>
#       <td id="T_31584_row2_col8" class="data row2 col8" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_31584_level0_row3" class="row_heading level0 row3" >piano</th>
#       <td id="T_31584_row3_col0" class="data row3 col0" >0.90</td>
#       <td id="T_31584_row3_col1" class="data row3 col1" >0.87</td>
#       <td id="T_31584_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_31584_row3_col3" class="data row3 col3" >0.90</td>
#       <td id="T_31584_row3_col4" class="data row3 col4" >0.91</td>
#       <td id="T_31584_row3_col5" class="data row3 col5" >0.90</td>
#       <td id="T_31584_row3_col6" class="data row3 col6" >0.91</td>
#       <td id="T_31584_row3_col7" class="data row3 col7" >0.87</td>
#       <td id="T_31584_row3_col8" class="data row3 col8" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_31584_level0_row4" class="row_heading level0 row4" >trumpet</th>
#       <td id="T_31584_row4_col0" class="data row4 col0" >0.37</td>
#       <td id="T_31584_row4_col1" class="data row4 col1" >0.54</td>
#       <td id="T_31584_row4_col2" class="data row4 col2" >0.28</td>
#       <td id="T_31584_row4_col3" class="data row4 col3" >0.47</td>
#       <td id="T_31584_row4_col4" class="data row4 col4" >0.53</td>
#       <td id="T_31584_row4_col5" class="data row4 col5" >0.43</td>
#       <td id="T_31584_row4_col6" class="data row4 col6" >0.47</td>
#       <td id="T_3

# %%
#df_tex = df.groupby(['model', 'instrument']).mean().to_latex(float_format="%.2f", multicolumn=True, multirow=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 df_tex = df.groupby(['model', 'instrument']).mean().to_latex(float_format="%.2f", multicolumn=True, multirow=True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# $$\\begin{array}{rrr}\n\\toprule\n precision &   recall &  f1-score \\\\\n  0.386935 & 0.440000 &  0.411765 \\\\\n\\midrule\n  0.755172 & 0.765734 &  0.760417 \\\\\n  0.373984 & 0.380165 &  0.377049 \\\\\n  0.876866 & 0.824561 &  0.849910 \\\\\n  0.501475 & 0.534591 &  0.517504 \\\\\n  0.673387 & 0.745536 &  0.707627 \\\\\n  0.442478 & 0.285714 &  0.347222 \\\\\n  0.772308 & 0.877622 &  0.821604 \\\\\n  0.463415 & 0.314050 &  0.374384 \\\\\n  0.895833 & 0.905263 &  0.900524 \\\\\n  0.548507 & 0.462264 &  0.501706 \\\\\n  0.742537 & 0.888393 &  0.808943 \\\\\n  0.500000 & 0.302857 &  0.377224 \\\\\n  0.777429 & 0.867133 &  0.819835 \\\\\n  0.395604 & 0.297521 &  0.339623 \\\\\n  0.885135 & 0.919298 &  0.901893 \\\\\n  0.544828 & 0.496855 &  0.519737 \\\\\n  0.730216 & 0.906250 &  0.808765 \\\\\n  0.363636 & 0.045714 &  0.081218 \\\\\n  0.728532 & 0.919580 &  0.812983 \\\\\n  0.452381 & 0.157025 &  0.233129 \\\\\n  0.869281 & 0.933333 &  0.900169 \\\\\n  0.542683 & 0.279874 &  0.369295 \\\\\n  0.706897 & 0.915179 &  0.797665 \\\\\n  0.546667 & 0.234286 &  0.328000 \\\\\n  0.781538 & 0.888112 &  0.831424 \\\\\n  0.500000 & 0.289256 &  0.366492 \\\\\n  0.907801 & 0.898246 &  0.902998 \\\\\n  0.526923 & 0.430818 &  0.474048 \\\\\n  0.715827 & 0.888393 &  0.792829 \\\\\n  0.000000 & 0.000000 &  0.000000 \\\\\n  0.709184 & 0.972028 &  0.820059 \\\\\n  0.533333 & 0.132231 &  0.211921 \\\\\n  0.872964 & 0.940351 &  0.905405 \\\\\n  0.568282 & 0.405660 &  0.473394 \\\\\n  0.718310 & 0.910714 &  0.803150 \\\\\n\\bottomrule\n\\end{array}\n$$

# %%
import pandas as pd

df = pd.DataFrame(results)

for model in models:
    for instrument in INSTRUMENTS:
        print("#" * 52)
        print("{} - {}, Accuracy: {}\n".format(model, instrument, results[model]['accuracy'][instrument]))
        print(results[model]['report'][instrument])
    
    break

df.head()
# Out:
#                                                RandomForest  \
# model     {'flute': (DecisionTreeClassifier(max_features...
# report    {'flute': '              precision    recall  ...
# accuracy  {'flute': 0.701067615658363, 'guitar': 0.76376...
#
#                                                         SVM  \
# model     {'flute': SVC(), 'guitar': SVC(), 'organ': SVC...
# report    {'flute': '              precision    recall  ...
# accuracy  {'flute': 0.6886120996441281, 'guitar': 0.7201...
#
#                                          LogisticRegression  \
# model     {'flute': LogisticRegression(max_iter=50), 'gu...
# report    {'flute': '              precision    recall  ...
# accuracy  {'flute': 0.6779359430604982, 'guitar': 0.7224...
#
#                                               GradientBoost  \
# model     {'flute': ([DecisionTreeRegressor(criterion='f...
# report    {'flute': '              precision    recall  ...
# accuracy  {'flute': 0.6690391459074733, 'guitar': 0.7477...
#
#                                                DecisionTree  \
# model     {'flute': DecisionTreeClassifier(), 'guitar': ...
# report    {'flute': '              precision    recall  ...
# accuracy  {'flute': 0.6120996441281139, 'guitar': 0.6834...
#
#                                                        LGBM
# model     {'flute': LGBMClassifier(), 'guitar': LGBMClas...
# report    {'flute': '              precision    recall  ...
# accuracy  {'flute': 0.6886120996441281, 'guitar': 0.75, ...
